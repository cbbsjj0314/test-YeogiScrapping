# %% [markdown]
# # Library

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException
import time

import requests
import datetime

import pandas as pd

# %% [markdown]
# # Parameter

# %%
list_base_url = "https://www.yeogi.com/domestic-accommodations?"
region_list = ["경기", "제주도", "충남", "인천", "대구", "대전", "서울", "경남", "부산", "전북", "울산", "광주", "강원", "경북", "전남", "충북", "세종"]
Category = 2

# %%
def weekday_setting_url(base_url, Category, Keyword):
    # cron tab : 0 => 월요일
    monday_date = "2024-11-11" # cron 시 : datetime.datetime.now().strftime("%Y-%m-%d")
    friday_date = "2024-11-15" # cron 시 : (datetime.datetime.now() + datetime.timedelta(days=4)).strftime("%Y-%m-%d")
    
    weekday_parameter = f"keyword={Keyword}&autoKeyword=&checkIn={monday_date}&checkOut={friday_date}&personal=2&freeForm=false&category={Category}&" #page={page}
    
    url = base_url+weekday_parameter
    return url

def holiday_setting_url(base_url, Category, Keyword):
    saturday_date = "2024-11-16" # cron 시 : (datetime.datetime.now() + datetime.timedelta(days=5)).strftime("%Y-%m-%d")
    sunday_date = "2024-11-17" # cron 시 : (datetime.datetime.now() + datetime.timedelta(days=6)).strftime("%Y-%m-%d")
    
    holiday_parameter = f"keyword={Keyword}&autoKeyword=&checkIn={saturday_date}&checkOut={sunday_date}&personal=2&freeForm=false&category={Category}&" #page={page}
    
    url = base_url+holiday_parameter
    return url

#####################
# Setting Dataframe #
#####################
def Make_Basic_DataFrame():
    # Dataframe 셋팅
    accommodations_frame = {
        'accommodation_id': [],
        'accommodation_MainCategory': [],
        'accomdation_SubCtegory' : [],
        'accomodations_Name' : []
    }
    accommodations_df = pd.DataFrame(accommodations_frame)
        
    price_frame = {
        'accommodation_id': [],
        'Date_Type' : [],
        'price': []
    }
    price_df = pd.DataFrame(price_frame)
        
    review_frame = {
        'accommodation_id': [],
        'accommodations_Rating': [],
        'accomodations_Review' : []
    }
    review_df = pd.DataFrame(review_frame)
    return accommodations_df, price_df, review_df

####################
# Crawling Setting #
####################
def crawling_setting():
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Run in headless mode (without GUI)
    chrome_options.add_argument("--no-sandbox")  # Bypass OS security model
    chrome_options.add_argument("--disable-dev-shm-usage")  # Overcome limited resource problems

    # Initialize the Chrome driver
    driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=chrome_options)
    return driver

##################
# Crawling Basic #
##################
def extract_accommodation_price(element):  
    """Extract price from the accommodation element."""
    try:
        price_element = element.find_element(By.CLASS_NAME, "css-5r5920")
        price_text = price_element.text.strip().replace(',', '')  # Remove commas
        return int(price_text)  # Convert to integer
    except NoSuchElementException:
        print("Price element not found, skipping this element.")
        return None  # Return None if not found
    except Exception as e:
        print(f"An error occurred while extracting the price: {e}")
        return None  # Return None if any other error occurs

def extract_accommodation_data(element):
    """Extract various details from an accommodation element."""
    try:
        # Extract Accommodation ID
        href = element.get_attribute("href")
        Accommodation_ID = href.split('/')[-1].split('?')[0]

        # Extract Name
        Accommodation_Name = element.find_element(By.CLASS_NAME, "gc-thumbnail-type-seller-card-title").text.strip()

        # Extract Rating and Review
        review_rating = element.find_element(By.CLASS_NAME, "css-9ml4lz").text.strip()  # Rating
        review_count_text = element.find_element(By.CLASS_NAME, "css-oj6onp").text.strip()  # Review Count
        review_count_numeric = ''.join(filter(str.isdigit, review_count_text))  # Extract only digits
        review_count = int(review_count_numeric) if review_count_numeric else 0  # Default to 0 if empty

        # Extract Accommodation Subcategory
        ul_element = element.find_element(By.CLASS_NAME, "css-19akvy6")
        li_elements = ul_element.find_elements(By.TAG_NAME, "li")
        Accomodation_SubCategory = "_".join([li.text for li in li_elements])

        return Accommodation_ID, Accommodation_Name, review_rating, review_count, Accomodation_SubCategory
    
    except Exception as e:
        print(f"An error occurred while extracting data: {e}")
        return None  # Return None if any error occurs
    
def update_dataframes(accommodations_df, price_df, review_df, temp_accommodations, temp_prices, temp_reviews):
    """Update DataFrames with new data."""
    accommodations_df = pd.concat([accommodations_df, pd.DataFrame(temp_accommodations)], ignore_index=True)
    price_df = pd.concat([price_df, pd.DataFrame(temp_prices)], ignore_index=True)
    review_df = pd.concat([review_df, pd.DataFrame(temp_reviews)], ignore_index=True)
    return accommodations_df, price_df, review_df

def scrape_accommodation(driver, base_url, date_type, Category, Keyword_list):
    accommodation_df, price_df, review_df = Make_Basic_DataFrame()
    
    for Keyword in Keyword_list:
        print("Crawling Start KeyWord : ", Keyword )
        page = 1
        
        if date_type == "Weekday":
            Keyword_base_url = weekday_setting_url(base_url, Category, Keyword)
        else:
            Keyword_base_url = holiday_setting_url(base_url, Category, Keyword)   
        
        print("Crawling_baseurl : ", base_url)
        
        while True:
            url = Keyword_base_url+f"page={page}"
            print("crawling_url : ", url)
            driver.get(url)

            elements = driver.find_elements(By.CLASS_NAME, "gc-thumbnail-type-seller-card")
            
            if not elements:
                print("No more elements found. Exiting...")
                break
            
            temp_accommodations = []
            temp_prices = []
            temp_reviews = []
            
            for element in elements:
                # Extract price
                price = extract_accommodation_price(element)
                if price is None:
                    continue  # Skip this iteration if price is not found
                
                # Extract accommodation data
                extracted_data = extract_accommodation_data(element)
                if extracted_data is None:
                    continue  # Skip if there was an error extracting data
                
                Accommodation_ID, Accommodation_Name, review_rating, review_count, Accomodation_SubCategory = extracted_data
            
                temp_accommodations.append({
                        'accommodation_id': Accommodation_ID,
                        'accommodation_MainCategory': "Hotel_Resort",
                        'accomdation_SubCtegory': Accomodation_SubCategory,
                        'accomodations_Name': Accommodation_Name
                })

                temp_prices.append({
                    'accommodation_id': Accommodation_ID,
                    'Date_Type': "Holiday",  # Use the provided date type
                    'price': price
                })

                temp_reviews.append({
                    'accommodation_id': Accommodation_ID,
                    'accommodations_Rating': review_rating,
                    'accomodations_Review': review_count
                })
                
            accommodation_df, price_df, review_df = update_dataframes(accommodation_df, price_df, review_df, temp_accommodations, temp_prices, temp_reviews)
            page += 1
            
    return accommodation_df, price_df, review_df

# %%
driver = crawling_setting()

accommodation_df, price_df, review_df  = scrape_accommodation(driver, list_base_url, "Weekday", Category, region_list)
# Out:
# Crawling Start KeyWord :  경기
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=7
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=8
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경기&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=9
# No more elements found. Exiting...
# Crawling Start KeyWord :  제주도
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=7
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=8
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=9
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=10
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=11
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=12
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=13
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=제주도&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=14
# No more elements found. Exiting...
# Crawling Start KeyWord :  충남
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# No more elements found. Exiting...
# Crawling Start KeyWord :  인천
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=인천&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=인천&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=인천&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=인천&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=인천&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=인천&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# No more elements found. Exiting...
# Crawling Start KeyWord :  대구
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대구&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대구&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대구&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대구&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# No more elements found. Exiting...
# Crawling Start KeyWord :  대전
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대전&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대전&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=대전&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# No more elements found. Exiting...
# Crawling Start KeyWord :  서울
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=7
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=8
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=9
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=10
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=11
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=12
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=13
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=서울&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=14
# No more elements found. Exiting...
# Crawling Start KeyWord :  경남
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=7
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=8
# No more elements found. Exiting...
# Crawling Start KeyWord :  부산
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=7
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=8
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=9
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=10
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=11
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=부산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=12
# No more elements found. Exiting...
# Crawling Start KeyWord :  전북
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# No more elements found. Exiting...
# Crawling Start KeyWord :  울산
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=울산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=울산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=울산&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# No more elements found. Exiting...
# Crawling Start KeyWord :  광주
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=광주&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=광주&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=광주&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=광주&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# No more elements found. Exiting...
# Crawling Start KeyWord :  강원
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=7
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=8
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=9
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=10
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=강원&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=11
# No more elements found. Exiting...
# Crawling Start KeyWord :  경북
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=경북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# No more elements found. Exiting...
# Crawling Start KeyWord :  전남
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=4
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=5
# An error occurred while extracting data: Message: no such element: Unable to locate element: {"method":"css selector","selector":".css-9ml4lz"}
#   (Session info: chrome=130.0.6723.60); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00CB38B3+24035]
# 	(No symbol) [0x00C3BC44]
# 	(No symbol) [0x00B1C2D3]
# 	(No symbol) [0x00B5DC86]
# 	(No symbol) [0x00B5DECB]
# 	(No symbol) [0x00B53CE1]
# 	(No symbol) [0x00B7FED4]
# 	(No symbol) [0x00B53C04]
# 	(No symbol) [0x00B80124]
# 	(No symbol) [0x00B9953F]
# 	(No symbol) [0x00B7FC26]
# 	(No symbol) [0x00B5218C]
# 	(No symbol) [0x00B5310D]
# 	GetHandleVerifier [0x00F596D3+2800643]
# 	GetHandleVerifier [0x00FB428E+3172286]
# 	GetHandleVerifier [0x00FACEA2+3142610]
# 	GetHandleVerifier [0x00D56C60+692624]
# 	(No symbol) [0x00C44C5D]
# 	(No symbol) [0x00C41968]
# 	(No symbol) [0x00C41B00]
# 	(No symbol) [0x00C33FB0]
# 	BaseThreadInitThunk [0x76E7FCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x7721809E+286]
# 	RtlGetAppContainerNamedObjectPath [0x7721806E+238]
#
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=전남&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=6
# No more elements found. Exiting...
# Crawling Start KeyWord :  충북
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=충북&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=3
# No more elements found. Exiting...
# Crawling Start KeyWord :  세종
# Crawling_baseurl :  https://www.yeogi.com/domestic-accommodations?
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=세종&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=1
# crawling_url :  https://www.yeogi.com/domestic-accommodations?keyword=세종&autoKeyword=&checkIn=2024-11-11&checkOut=2024-11-15&personal=2&freeForm=false&category=2&page=2
# No more elements found. Exiting...

# %%
accommodation_df
# Out:
#      accommodation_id accommodation_MainCategory accomdation_SubCtegory  \
# 0               69476               Hotel_Resort              블랙_4성급_호텔
# 1               75023               Hotel_Resort                레지던스_호텔
# 2               67765               Hotel_Resort                 4성급_호텔
# 3                6877               Hotel_Resort                 3성급_호텔
# 4               58125               Hotel_Resort                 3성급_호텔
# ...               ...                        ...                    ...
# 1726            67758               Hotel_Resort                 4성급_호텔
# 1727            62500               Hotel_Resort                비즈니스_호텔
# 1728             6673               Hotel_Resort                 3성급_호텔
# 1729            45159               Hotel_Resort                 3성급_호텔
# 1730            79585               Hotel_Resort                가족호텔_호텔
#
#        accomodations_Name
# 0             테이크 호텔 서울광명
# 1          르컬렉티브 시흥 웨이브파크
# 2      나인트리 바이 파르나스 서울 판교
# 3         [반짝특가] 신라스테이 동탄
# 4     라마다 앙코르 바이 윈덤 김포 한강
# ...                   ...
# 1726     베스트웨스턴 플러스 호텔 세종
# 1727          오송 H호텔 세종시티
# 1728                 세종호텔
# 1729              춘천 세종호텔
# 1730           초정약수 세종스파텔
#
# [1731 rows x 4 columns]

# %%
price_df
# Out:
#      accommodation_id Date_Type     price
# 0               69476   Holiday  135000.0
# 1               75023   Holiday   66624.0
# 2               67765   Holiday  157650.0
# 3                6877   Holiday  126660.0
# 4               58125   Holiday  118342.0
# ...               ...       ...       ...
# 1726            67758   Holiday  160000.0
# 1727            62500   Holiday  150000.0
# 1728             6673   Holiday  172500.0
# 1729            45159   Holiday   72800.0
# 1730            79585   Holiday   70000.0
#
# [1731 rows x 3 columns]

# %%
review_df
# Out:
#      accommodation_id accommodations_Rating  accomodations_Review
# 0               69476                   9.3                1297.0
# 1               75023                   9.3                 702.0
# 2               67765                   9.4                 934.0
# 3                6877                   9.5                2926.0
# 4               58125                   9.0                1580.0
# ...               ...                   ...                   ...
# 1726            67758                   9.4                 263.0
# 1727            62500                   9.3                 275.0
# 1728             6673                   9.0                 766.0
# 1729            45159                   8.4                 221.0
# 1730            79585                   7.6                   9.0
#
# [1731 rows x 3 columns]
